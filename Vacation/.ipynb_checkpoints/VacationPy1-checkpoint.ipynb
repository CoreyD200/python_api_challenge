# %%
#import dependencies

import pandas as pd
import gmaps
import csv
import requests
import json
from ipywidgets.embed import embed_minimal_html

# Google developer API key
from config import gkey

# %%
#get data file

datafile = ('..\Weather\WeatherData.csv')
weather_data=pd.read_csv(datafile)
weather_data.head()
# Out:
#          City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0      Avarua         100      CK  1580053365        88 -21.21 -159.78
# 1  Chokurdakh         100      RU  1580053365        96  70.63  147.92
# 2      Albany          90      US  1580053365        80  42.60  -73.97
# 3     Isangel          82      VU  1580053365        88 -19.55  169.27
# 4   Cape Town          40      ZA  1580053366        49 -33.93   18.42
#
#    Max Temp  Wind Speed
# 0     80.60       11.41
# 1    -18.56        4.72
# 2     39.00        6.93
# 3     73.40        2.24
# 4     71.01       19.46

# %%
gmaps.configure(api_key=gkey)

# %%
coordinates = weather_data[['Lat','Lng']]

humidity = weather_data['Humidity']

# %%
# Customize the size of the figure
figure_layout = {
    'width': '900px',
    'height': '400px',
    'border': '10px solid black',
    'padding': '1px',
    'margin': '0 auto 0 auto'
}

fig = gmaps.figure(layout=figure_layout, zoom_level=1.75, center=(20,35))

heat_map = gmaps.heatmap_layer(coordinates, weights = humidity, dissipating = False,
                               max_intensity = 205, point_radius= 3)

fig.add_layer(heat_map)


embed_minimal_html('heatmap.html', views=[fig])
fig
# Out:
# Figure(layout=FigureLayout(border='10px solid black', height='400px', margin='0 auto 0 auto', padding='1px', width='900px'))

# %%
# set ideal temperature range from 65 to 75
# set ideal Max windspeed at 8 mph
# set ideal cloudiness to 5% or less

mintempDF= weather_data.loc[weather_data['Max Temp']>65]
itempDF= mintempDF.loc[mintempDF['Max Temp'] < 78]
iwindDF= itempDF.loc[itempDF["Wind Speed"] < 8]
idealDF= iwindDF.loc[iwindDF["Cloudiness"] < 5]

# %%
len(idealDF)
# Out:
# 12

# %%
# add a column for Hotel name to new DF
idealDF["Hotel"]=""
# output column headers to confirm the field was added
idealDF.columns
# Out:
# D:\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# Index(['City', 'Cloudiness', 'Country', 'Date', 'Humidity', 'Lat', 'Lng',
#        'Max Temp', 'Wind Speed', 'Hotel'],
#       dtype='object')

# %%
# get base url for google nearby search
base_url = 'https://maps.googleapis.com/maps/api/place/nearbysearch/json'

# %%
target_search = "Hotel"
target_radius = 5000


# set up parameters dictionary
params = {
    "radius" : target_radius,
    "target_type" : target_search,
    'key': gkey,
    }

for index, row in idealDF.iterrows():
    
    lat = row['Lat']
    long = row["Lng"]
    params['location']= f'{lat},{long}'
    
    response = requests.get(base_url, params = params)
    hotel_data= response.json()
    
    try:
        idealDF.loc[index, "Hotel"] = hotel_data['results'][0]['name']
        
    except (KeyError, IndexError):
        print("Hotel data not available for this location. Moving on to next city")
    
print(response.url)    
print(json.dumps(hotel_data, indent = 4))
# Out:
# D:\Anaconda3\lib\site-packages\pandas\core\indexing.py:537: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# https://maps.googleapis.com/maps/api/place/nearbysearch/json?radius=5000&target_type=Hotel&key=AIzaSyB7oi7WtKHQjCDDPFU5lbUW9_z9ZEd64T8&location=20.9%2C70.37
# {
#     "html_attributions": [],
#     "next_page_token": "CqQCFQEAANuhN2Dy5GxG14Gfd4iEsnlGcbv7tOO4r70j5OyrCtR57g2mZlCt5oNiNxo0tqOgp54xLZPnVeJLH1vnhZzILO-YLKp_kYoUtKiDSWtk1HnEL7X6okBHNZfyMZ0I01OVnDQeSCvfLTWJHUSQaNU7jjlgJBMGbQ6uFZhYIpuWcYkfVHijNdRPdcV3oPA_vVu23rOLq4scw3RY4o4DKIUqUmg3qcCClPG6fAigNbS8tNjkHZuz6o4VgUZpC35ERyWhkkVcw1SEANJ4nvZ9_eUcOxhF3QAKm4lbd_joWk4EL2vjlgoBuNsEn8350VuAVN9cZh9DNr6uu8Sz32LcUWX9T7kXi8Wbg5HHWRhSfuZGweE3eoch9FrTcAq2-GpSZBFpZBIQZQGX3SV7qOxam2Ffe7uLSxoUFFa8D6tVL0vySwth4OuHD5cBlhw",
#     "results": [
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 20.9158979,
#                     "lng": 70.3628516
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 20.9329033,
#                         "lng": 70.3718973
#                     },
#                     "southwest": {
#                         "lat": 20.9019923,
#                         "lng": 70.346403
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/geocode-71.png",
#             "id": "4e92fb39333d117f4ba036707a22c94391f7ea7d",
#             "name": "Veraval",
#             "photos": [
#                 {
#                     "height": 960,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/116098649618874320513\">Manish Motivaras</a>"
#                     ],
#                     "photo_reference": "CmRaAAAA6CsUKRa-_5MdOkhm8ivZFuN2u3pQ3zIoXjHV41VGWgDiEcOBxaaCxow7gH6AkR0MZZZBpZyx2TJGDp6LRd4dlmOYr9eN95c_GXaC0yXtwwKlMvpnh49ZlVpnRFc6g7-OEhCRAvjRqLVsDGFH15rLckt1GhT-u2dX0lccnt9YL_V2MA3qQwS9bQ",
#                     "width": 1280
#                 }
#             ],
#             "place_id": "ChIJW6uWiTAy_TsRd6e_CRtHhfI",
#             "reference": "ChIJW6uWiTAy_TsRd6e_CRtHhfI",
#             "scope": "GOOGLE",
#             "types": [
#                 "locality",
#                 "political"
#             ],
#             "vicinity": "Veraval"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 20.8956329,
#                     "lng": 70.41038739999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 20.8970818802915,
#                         "lng": 70.4117144802915
#                     },
#                     "southwest": {
#                         "lat": 20.8943839197085,
#                         "lng": 70.40901651970849
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "99db8038e8533ab8cc90d8502be5a780e03fab02",
#             "name": "Lords Inn Somnath",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 449,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/115187289149629611262\">Lords Inn Somnath</a>"
#                     ],
#                     "photo_reference": "CmRaAAAA9PYLjiEi2k91I-1KHIh7Khx7PAxS9UakgumGyhNgH68vutefDbxyTZb2_qHKGFvQ7Z5Y4EZ7KGMJbyua8YESvFtxXF8jmCTkg-pieCuavr8LZMlQeHuvuWEgcathYWY1EhBUcF2NatI9W0zjTYCz2xKaGhS3QoZ0LMMeYXsY6jb9cVUn-qaKTw",
#                     "width": 800
#                 }
#             ],
#             "place_id": "ChIJe8KY1aIy_TsRYmL3YLqYtwo",
#             "plus_code": {
#                 "compound_code": "VCW6+75 Veraval, Gujarat, India",
#                 "global_code": "7JGGVCW6+75"
#             },
#             "rating": 4.5,
#             "reference": "ChIJe8KY1aIy_TsRYmL3YLqYtwo",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 3531,
#             "vicinity": "Somnath, Somnath By-PassRoad, Prabhash Patan, Veraval"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 20.9101379,
#                     "lng": 70.3640291
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 20.9114222302915,
#                         "lng": 70.3653702302915
#                     },
#                     "southwest": {
#                         "lat": 20.9087242697085,
#                         "lng": 70.3626722697085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "1c30c6d36db14285f3e5413c9db0c3b0ef4e2892",
#             "name": "Hotel Raghav",
#             "photos": [
#                 {
#                     "height": 3000,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/106159883882129765359\">Jayesh Kishor</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAnDnsxmEwLhVO4lEJ6Af3h39Qqgn0Ceia7w_DXNHQfUpr_sg4wZus_4UTlsHQyIzO0z3eDh5dTheGXgDiOJAfgxCRh_zMHSu5VPsJa5SH0eZ2eCLVkjuBKK9V9K7opQmmEhACtyhixBSlu9i336AYtVHIGhSSKWPsn9iHNcPdPFDR4p4DgkoFlQ",
#                     "width": 4000
#                 }
#             ],
#             "place_id": "ChIJX91-j0Yy_TsRRhigf3fUguE",
#             "plus_code": {
#                 "compound_code": "W967+3J Veraval, Gujarat, India",
#                 "global_code": "7JGGW967+3J"
#             },
#             "rating": 3.6,
#             "reference": "ChIJX91-j0Yy_TsRRhigf3fUguE",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 114,
#             "vicinity": "Sathguru Arcade, Near Tower Chowk, Floor No. 3, Veraval"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 20.9291131,
#                     "lng": 70.352942
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 20.9304208802915,
#                         "lng": 70.35429263029151
#                     },
#                     "southwest": {
#                         "lat": 20.9277229197085,
#                         "lng": 70.3515946697085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "04b941912938f93d6b886446c99d0c39e5139a20",
#             "name": "Hotel Heritage veraval somnath",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 2304,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/101608333651636917920\">Ravi raj</a>"
#                     ],
#                     "photo_reference": "CmRaAAAA4BnKi3ReXNo-_GasdZjdKABZlndwSIQMpODK9w5iQbWRSSjDyMomnG2FZzy5uBhNJDyIG5fK41OwMIwH9ShNnTWb_Th6XTndY9An2CNen1DsjGMbPufIcT6F9nlefKm2EhC5onrbJJq99GoX4anMu3KCGhTodqDi4Zp2mT1ipDSFf_fbFSJ1Kw",
#                     "width": 4608
#                 }
#             ],
#             "place_id": "ChIJoduaqM4z_TsRKKUZCsLkdu4",
#             "plus_code": {
#                 "compound_code": "W9H3+J5 Veraval, Gujarat, India",
#                 "global_code": "7JGGW9H3+J5"
#             },
#             "rating": 4,
#             "reference": "ChIJoduaqM4z_TsRKKUZCsLkdu4",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 512,
#             "vicinity": "opp. saibaba temple, veraval, Veraval Junagadh Road, opp. saibaba temple, Veraval"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 20.9203547,
#                     "lng": 70.3573301
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 20.9216758802915,
#                         "lng": 70.3586145802915
#                     },
#                     "southwest": {
#                         "lat": 20.9189779197085,
#                         "lng": 70.3559166197085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "a9a7f1a9ebfa392c6fe4c519a0fc9b777a72c8f2",
#             "name": "Hotel Woodland Somnath",
#             "photos": [
#                 {
#                     "height": 1080,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/114683272419158265827\">raj kushwaha</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAXp4IaOdXTibhUXCkBlIWgEn4KKONbMvPGyFCU8w2R-ajCZeE9RPkmm2hRgXwvERH34urxCFFoFhv_x0GmBRyJp9Ds8V7o-EHgp6axQ9rn4XIcTtdfRjTo_vRLQ2JaQBfEhCu5v0C-ZjFWmpcHSL8LMKaGhTLFLxgi-L1F9u5S4z9f21nKitmAA",
#                     "width": 1920
#                 }
#             ],
#             "place_id": "ChIJv-V1rjUy_TsR8NcjG3JtlNc",
#             "plus_code": {
#                 "compound_code": "W9C4+4W Veraval, Gujarat, India",
#                 "global_code": "7JGGW9C4+4W"
#             },
#             "rating": 3.7,
#             "reference": "ChIJv-V1rjUy_TsR8NcjG3JtlNc",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 278,
#             "vicinity": "opp. Indian Rayon, Junagadh Road, Veraval, opp. Indian Rayon"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 20.9089288,
#                     "lng": 70.36829019999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 20.9103435302915,
#                         "lng": 70.3696331802915
#                     },
#                     "southwest": {
#                         "lat": 20.9076455697085,
#                         "lng": 70.36693521970848
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/lodging-71.png",
#             "id": "5b466f6015098e18ee91be3a20267f8449ac2069",
#             "name": "Hotel SUKUN",
#             "photos": [
#                 {
#                     "height": 408,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/102171881794747171485\">Fezal Gadhiya</a>"
#                     ],
#                     "photo_reference": "CmRaAAAA8vRlH7kjP4Uzl_BBOTI2k02ay0-1vHpaAf1CqVLC3ylghIeU8c4DyhI31Gm3onwHZZQTQNBa70jQ2Yepu8p0yDqUfVsRKa66QkoZbTyjWLBwSpOA5OHmAxQY7pZJEwh_EhCUq8tAHf7Nz05Oms1GqyIqGhTjbZM3kB2RlMSLS_epmZZ8alGU8g",
#                     "width": 544
#                 }
#             ],
#             "place_id": "ChIJ-YtPZEQy_TsRk9exseuKQso",
#             "plus_code": {
#                 "compound_code": "W959+H8 New Patelwada, Viraval Village, Veraval, Gujarat, India",
#                 "global_code": "7JGGW959+H8"
#             },
#             "rating": 3.8,
#             "reference": "ChIJ-YtPZEQy_TsRk9exseuKQso",
#             "scope": "GOOGLE",
#             "types": [
#                 "lodging",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 253,
#             "vicinity": "Behind GEB, Near Rambharaosa Police Chowki Veraval Gujarat 362265 IN"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 20.9119575,
#                     "lng": 70.363828
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 20.9132299802915,
#                         "lng": 70.3651955802915
#                     },
#                     "southwest": {
#                         "lat": 20.9105320197085,
#                         "lng": 70.36249761970849
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png",
#             "id": "4e1a83ffe056c2ede3692f8f0d0d7f71e3724607",
#             "name": "Shiv Photo Art",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 2359,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/110965204393347736913\">Sunny Vaja</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAKhgOVtNU7aqrceWXpAPGBkf66ulKw9peYaQVs5BziTVkQnXyMBEON-1v4sWUzB3WXvtua-tNraJpGhKc4kZxA13w-jIy2IfxiI-L5QTk9GhvHnWi5dygaBKBEANiHFTXEhBYGOEXPxRHO7MifmexbqabGhQghA7g-YVOP8gGrnMznED_2NTuwA",
#                     "width": 4193
#                 }
#             ],
#             "place_id": "ChIJi4dAMUYy_TsR3eaGDrUmsGs",
#             "plus_code": {
#                 "compound_code": "W967+QG Veraval, Gujarat, India",
#                 "global_code": "7JGGW967+QG"
#             },
#             "rating": 3.6,
#             "reference": "ChIJi4dAMUYy_TsR3eaGDrUmsGs",
#             "scope": "GOOGLE",
#             "types": [
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 8,
#             "vicinity": "opp. Lakhani Hospital, Paramhans App. Shop No. 6, opp. Lakhani Hospital, Veraval"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 20.9113187,
#                     "lng": 70.3595527
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 20.9122419802915,
#                         "lng": 70.36104748029149
#                     },
#                     "southwest": {
#                         "lat": 20.9095440197085,
#                         "lng": 70.35834951970848
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/doctor-71.png",
#             "id": "14715a1c38a9b033ed5fb44958f8efd7f8c4e5ab",
#             "name": "Civil Hospital",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 4160,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/116003576741942792897\">Shailesh Mehta</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAPTQEz78L8Pi49EJc55i46HG-mcMXAicmpfxeC8lyQi8e1qRdKqo6F-lyyjBOjszjQA4zvMzC23BgVS71kFFih4cg2subVfZFRwE1DIdvaaaZaFPmifu8DxrnLI7IZOE2EhD9x9XCassqqWfynWJ7d-5WGhTaLlrC_nAPm9unOHpogjCLMa4l0w",
#                     "width": 3120
#                 }
#             ],
#             "place_id": "ChIJEw23jUcy_TsRzyAzbEQaELM",
#             "plus_code": {
#                 "compound_code": "W965+GR Veraval, Gujarat, India",
#                 "global_code": "7JGGW965+GR"
#             },
#             "rating": 3.7,
#             "reference": "ChIJEw23jUcy_TsRzyAzbEQaELM",
#             "scope": "GOOGLE",
#             "types": [
#                 "hospital",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 28,
#             "vicinity": "Rajendra Bhuvan Road, Veraval"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 20.9114359,
#                     "lng": 70.3629097
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 20.9127618302915,
#                         "lng": 70.36423433029151
#                     },
#                     "southwest": {
#                         "lat": 20.9100638697085,
#                         "lng": 70.36153636970849
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png",
#             "id": "4ff8f81acdc71d687eeace89c1b3f853ecb43f63",
#             "name": "Apurva Properties",
#             "place_id": "ChIJnw8rS0Yy_TsRGpPZrCxZ8U4",
#             "plus_code": {
#                 "compound_code": "W967+H5 Veraval, Gujarat, India",
#                 "global_code": "7JGGW967+H5"
#             },
#             "rating": 5,
#             "reference": "ChIJnw8rS0Yy_TsRGpPZrCxZ8U4",
#             "scope": "GOOGLE",
#             "types": [
#                 "real_estate_agency",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1,
#             "vicinity": "Ganesh Offset, 29 Riddhi Siddhi Complex, S.T. Road, Veraval"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 20.9013491,
#                     "lng": 70.3929878
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 20.9027673802915,
#                         "lng": 70.3941331802915
#                     },
#                     "southwest": {
#                         "lat": 20.9000694197085,
#                         "lng": 70.3914352197085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png",
#             "id": "f2a1a0d5fd3491e01a04d05c39a95de9b4db1177",
#             "name": "Keshodwala Foods",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 3096,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/107282574183846825619\">Bhavesh Murabia</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAIYHzZo-Hl6elG9tuUaD7kGVjDIQDEiFv1Ev2LS7pmgIclrNJs8bJvA8X3R0zTXQRXSkEl4pk4GZi4Ywd9SOrqKzDWmBgmdpmsFtIgi5dGhdoAEWpU8mZRUxYlUVbFSZ3EhAIwsngWt-4IoqkM9mLrL0gGhQQpadRwnCpYlG4VueMRCpdL9xWLw",
#                     "width": 4128
#                 }
#             ],
#             "place_id": "ChIJtal4hIwy_TsR_Hwt2CZuP24",
#             "plus_code": {
#                 "compound_code": "W92V+G5 Somnath, Gujarat, India",
#                 "global_code": "7JGGW92V+G5"
#             },
#             "rating": 4.5,
#             "reference": "ChIJtal4hIwy_TsR_Hwt2CZuP24",
#             "scope": "GOOGLE",
#             "types": [
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 25,
#             "vicinity": "Somnath"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 20.911495,
#                     "lng": 70.362674
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 20.9128562802915,
#                         "lng": 70.3640371302915
#                     },
#                     "southwest": {
#                         "lat": 20.9101583197085,
#                         "lng": 70.3613391697085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png",
#             "id": "c9893bced1dbff4a9fbd2eca65b7266d4f3c70ab",
#             "name": "LIC OF INDIA",
#             "place_id": "ChIJTYYKtUcy_TsRRHChgRjbQ54",
#             "plus_code": {
#                 "compound_code": "W967+H3 Veraval, Gujarat, India",
#                 "global_code": "7JGGW967+H3"
#             },
#             "rating": 1.5,
#             "reference": "ChIJTYYKtUcy_TsRRHChgRjbQ54",
#             "scope": "GOOGLE",
#             "types": [
#                 "finance",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 2,
#             "vicinity": "Lohana Boarding Building,, Opp State Transport Station, Veraval Gujarat India"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 20.9075357,
#                     "lng": 70.36517789999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 20.9088857302915,
#                         "lng": 70.3665617802915
#                     },
#                     "southwest": {
#                         "lat": 20.9061877697085,
#                         "lng": 70.36386381970848
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/restaurant-71.png",
#             "id": "c6072bed6ae72e1f8767c85dc130319e47fe1806",
#             "name": "Kaka Sandwich",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 405,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/105358039432918397232\">Kaka Sandwich</a>"
#                     ],
#                     "photo_reference": "CmRaAAAA5Z8NjXm9QNOtP3RaCbNUAD_5x6KAoz5G1mI2JbofDvKy-sNp4Cn8I5EBTxGu8Ub7ynGOAntUkm0v9EWbDvfvYjkagSIVl6n5buXZYRg_-k2PzrUWVFF8nk9edWvFPcr3EhA9KAN_70Q2Vz5vLoYb-iWVGhQaHJtXPO-VWRi-GtXoop_duxTXtA",
#                     "width": 720
#                 }
#             ],
#             "place_id": "ChIJ89mUUkEy_TsRe7iu04f5-90",
#             "plus_code": {
#                 "compound_code": "W958+23 Veraval, Gujarat, India",
#                 "global_code": "7JGGW958+23"
#             },
#             "rating": 4.4,
#             "reference": "ChIJ89mUUkEy_TsRe7iu04f5-90",
#             "scope": "GOOGLE",
#             "types": [
#                 "restaurant",
#                 "food",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 620,
#             "vicinity": "opp. Public Library, Bandar Road, Veraval"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 20.91128729999999,
#                     "lng": 70.3657509
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 20.9126469802915,
#                         "lng": 70.3672050302915
#                     },
#                     "southwest": {
#                         "lat": 20.9099490197085,
#                         "lng": 70.3645070697085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/civic_building-71.png",
#             "id": "aa3a5d9cd5cd1c19b57112e79a63761c6872351d",
#             "name": "Veraval MDG Post Office",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 2448,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/105801852955770791116\">Ketan Gondaliya</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAfZ8vnUHxjkzPah_umGywLDmzOuDwpGUQXmjtmmbx1PY8pn7yfJPjBcRqV7QVNELlZqp5QmPNZdgvMoqaHxLm4MXwPC8Sy3kjL70H_HGnQ0U71dLLerWWu30YrE1HBOCMEhBxTGKYHfbPflQYhxGyg_kcGhT1PGgXForxKPGSAxfLtR8W_AmtrQ",
#                     "width": 3264
#                 }
#             ],
#             "place_id": "ChIJNYeXd0Yy_TsRP_J6YM6DnBI",
#             "plus_code": {
#                 "compound_code": "W968+G8 Veraval, Gujarat, India",
#                 "global_code": "7JGGW968+G8"
#             },
#             "rating": 4.3,
#             "reference": "ChIJNYeXd0Yy_TsRP_J6YM6DnBI",
#             "scope": "GOOGLE",
#             "types": [
#                 "post_office",
#                 "finance",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 23,
#             "vicinity": "kodiwad, General Post Office Road, Rayon Housing Society, Veraval"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 20.9158979,
#                     "lng": 70.3628516
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 20.9178806302915,
#                         "lng": 70.36418608029152
#                     },
#                     "southwest": {
#                         "lat": 20.9151826697085,
#                         "lng": 70.3614881197085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png",
#             "id": "47195a356c20b00000c00de7342520fa48ff7f35",
#             "name": "Asian Impex Sea Foods Processor & Exporters",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 250,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/104056577676524808391\">Asian Impex Sea Foods Processor &amp; Exporters</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAoMJdZLsEr2DPAZQjmRo3n3o3YDSBKwLQ3T7g94chy3Mk0oaWKdAkHTMy0sUThSNvQauXn6s7khQpgibIIKDGvW4QaatypYqZZqMmKbqec7sShVrzs9o2hfX2-jlFKoIcEhAsDQ9jV6-H1WjDmXiUm51tGhQgq0NJgLRH_AXMwaURPVe_SLwIqg",
#                     "width": 250
#                 }
#             ],
#             "place_id": "ChIJH4_KqTAy_TsRxek6f9hdAJY",
#             "rating": 4.5,
#             "reference": "ChIJH4_KqTAy_TsRxek6f9hdAJY",
#             "scope": "GOOGLE",
#             "types": [
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 2,
#             "vicinity": "U- 1/2, Somnath Road, GIDC, Veraval"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 20.912003,
#                     "lng": 70.353376
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 20.9134133802915,
#                         "lng": 70.3549396802915
#                     },
#                     "southwest": {
#                         "lat": 20.9107154197085,
#                         "lng": 70.35224171970849
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png",
#             "id": "59a4746464f42ddccb1489241805205027010cdb",
#             "name": "Shree Travels ( Tous & Travel Booking Agent )",
#             "photos": [
#                 {
#                     "height": 375,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/105131329728207551154\">Shree Travels ( Tous &amp; Travel Booking Agent )</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAxJjBE0qS_9qqgxaNc8hmQxEO0AumsrDpDojfRo1z10q63FlZaDT7OABwt_Ke-FKGMJL_i2-5-gCmwQqAkcnSKkZakNTwXiqLGuZIAKHz9MFgdPpmxj7_19XfDNRKXi_REhDB4Zx1PUZvH8cpjBOSGNMgGhSgzpwqB_OlNwl5PTi7Wd-F-goDTg",
#                     "width": 500
#                 }
#             ],
#             "place_id": "ChIJH4_KqTAy_TsR-QfEwizKfZI",
#             "rating": 2.8,
#             "reference": "ChIJH4_KqTAy_TsR-QfEwizKfZI",
#             "scope": "GOOGLE",
#             "types": [
#                 "travel_agency",
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 4,
#             "vicinity": "Opp. Bus Stand, Chetna Rest House Building,, Veraval"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 20.909723,
#                     "lng": 70.377202
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 20.9110979802915,
#                         "lng": 70.3785417302915
#                     },
#                     "southwest": {
#                         "lat": 20.9084000197085,
#                         "lng": 70.3758437697085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png",
#             "id": "13ab35891b9e23d0421e31c90687f24a517d0447",
#             "name": "SHIVA BEATS",
#             "photos": [
#                 {
#                     "height": 1836,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/103503267998645830888\">Anil Srivastava</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAsLE3O2hRle8SRVHj2HtvFzv3cbM8PFO7uxiv4Kt3nyCUH3j2_Gq-FfoSTk8aViYZm7lXD-03sTMRcSCwiDINQJbBshQBBLP4VBPKfnNEfelxvjSLc4afvCidoPXTt5MfEhB2NKH9K0cII5fq3TFHXc6qGhSGqrGC2DMY9lte_co6wVqcrsk1Pg",
#                     "width": 3264
#                 }
#             ],
#             "place_id": "ChIJUxgv-1sy_TsR3VevfLFW1Is",
#             "plus_code": {
#                 "compound_code": "W95G+VV Veraval, Gujarat, India",
#                 "global_code": "7JGGW95G+VV"
#             },
#             "rating": 4.1,
#             "reference": "ChIJUxgv-1sy_TsR3VevfLFW1Is",
#             "scope": "GOOGLE",
#             "types": [
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 32,
#             "vicinity": "Shiva Beats, Nr Talala Naka, Bhalka Road, Veraval"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 20.9100136,
#                     "lng": 70.36787389999999
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 20.9112482802915,
#                         "lng": 70.3692218802915
#                     },
#                     "southwest": {
#                         "lat": 20.9085503197085,
#                         "lng": 70.3665239197085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/shopping-71.png",
#             "id": "ef379eed74ca7f84030e7c15cdc3a472145e37d8",
#             "name": "ZAS Infotech",
#             "opening_hours": {
#                 "open_now": false
#             },
#             "photos": [
#                 {
#                     "height": 1152,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/114178552462208062678\">ZAS Infotech</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAqOaElPC01y-fiiX6IyJCg-JX7K4NDW_Stb2bWXUMFRkGJwRqUD--k4G6QXBBO2Af7eSCHF9bLJVKrzKvwu1yO53fzMhVdYfKz12ca9CMzeF6-IePzpJ-9d7Peaj0GeyVEhAkFVuIwSthpR0JNp9-F3kaGhRjUTBdXC2RHJGwh2JoIuSn13_JLw",
#                     "width": 2048
#                 }
#             ],
#             "place_id": "ChIJjaYoT0Yy_TsRpHbIC9dKeq0",
#             "plus_code": {
#                 "compound_code": "W969+24 Veraval, Gujarat, India",
#                 "global_code": "7JGGW969+24"
#             },
#             "rating": 3.8,
#             "reference": "ChIJjaYoT0Yy_TsRpHbIC9dKeq0",
#             "scope": "GOOGLE",
#             "types": [
#                 "electronics_store",
#                 "point_of_interest",
#                 "store",
#                 "establishment"
#             ],
#             "user_ratings_total": 16,
#             "vicinity": "below phoenix restaurant, opp. pgvcl, Raj Mahal Road, Veraval"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 20.9213716,
#                     "lng": 70.38148860000001
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 20.9227648802915,
#                         "lng": 70.38282078029151
#                     },
#                     "southwest": {
#                         "lat": 20.9200669197085,
#                         "lng": 70.3801228197085
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png",
#             "id": "2f22dcb8b85d28f7b923b226920b21e3fe2501fb",
#             "name": "vinayak digital studio",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 864,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/116603906753478999273\">vinayak digital studio</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAw0-gJawhT3yKNOCN9wzb15Um5JXBREqu-JSAo30WRylpEInQ4bIgKjscXGsvkrdSZxBWU1tGuS1Eq8CCATz1YffWkL9LRxrP7Kol1ecXxTF4rnyBr9EISjouIwdIRHuOEhAnGfI2ALyEG_cGA5Yeg7RZGhQmfJdAKB6iJmpXrsyfNYh8cx67-Q",
#                     "width": 1728
#                 }
#             ],
#             "place_id": "ChIJH4_KqTAy_TsRmhrN1JPggvI",
#             "plus_code": {
#                 "compound_code": "W9CJ+GH Veraval, Gujarat, India",
#                 "global_code": "7JGGW9CJ+GH"
#             },
#             "rating": 2,
#             "reference": "ChIJH4_KqTAy_TsRmhrN1JPggvI",
#             "scope": "GOOGLE",
#             "types": [
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 1,
#             "vicinity": "Bus Station Road,Vodafone store street Opposite Makhan Shah Hospital, Veraval"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 20.9197831,
#                     "lng": 70.36415300000002
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 20.9211316802915,
#                         "lng": 70.3655067802915
#                     },
#                     "southwest": {
#                         "lat": 20.9184337197085,
#                         "lng": 70.36280881970849
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/generic_business-71.png",
#             "id": "f61bd946458a3494682aeb1911a21a94f85b4c1f",
#             "name": "Indigenous honey",
#             "opening_hours": {
#                 "open_now": true
#             },
#             "photos": [
#                 {
#                     "height": 3064,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/116956476436794126904\">Indigenous honey</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAsyQ7ov_7IGZBSshE9dKofkNds-eZCuIhr_Swj4dFTg4lqZpzNPgnYvhEQfDl-kIfu8I-WDUssa5B3QRRsxft_9E6m6I0ILwDAot23alQ2aUlw-cWfYdu_HjsYX9RWh8sEhC_rolrEhFs3jVB9N3QmgJZGhTXvG8tE7P5MqUgXjSs68G6Iuu-8Q",
#                     "width": 5456
#                 }
#             ],
#             "place_id": "ChIJhfvXUEoy_TsREh4ZEcmMaUc",
#             "plus_code": {
#                 "compound_code": "W997+WM Vidhyut Nagar, Veraval, Gujarat, India",
#                 "global_code": "7JGGW997+WM"
#             },
#             "rating": 4.8,
#             "reference": "ChIJhfvXUEoy_TsREh4ZEcmMaUc",
#             "scope": "GOOGLE",
#             "types": [
#                 "point_of_interest",
#                 "establishment"
#             ],
#             "user_ratings_total": 30,
#             "vicinity": "primitive corporation, c/o, 60 Feet Road, Vidhyut Nagar, Veraval"
#         },
#         {
#             "geometry": {
#                 "location": {
#                     "lat": 20.9146484,
#                     "lng": 70.3643395
#                 },
#                 "viewport": {
#                     "northeast": {
#                         "lat": 20.91796,
#                         "lng": 70.3704379
#                     },
#                     "southwest": {
#                         "lat": 20.909752,
#                         "lng": 70.358432
#                     }
#                 }
#             },
#             "icon": "https://maps.gstatic.com/mapfiles/place_api/icons/geocode-71.png",
#             "id": "1899983f525c8715b65305221e69de8e61e39d97",
#             "name": "Rayon Housing Society",
#             "photos": [
#                 {
#                     "height": 540,
#                     "html_attributions": [
#                         "<a href=\"https://maps.google.com/maps/contrib/117133798876908804906\">Janendr Singh Rajawat</a>"
#                     ],
#                     "photo_reference": "CmRaAAAAqwwUH8Ih3804hJLTBOR7vG4lZ8LBL2qg_vd8a5gcZw6MQMUDbqgu2Em9ISRuCirKouZWaOcS8lvRSOqcpyEsLDWnJ0KMIgqg84NLyQ0uuRjL6VZdEXfeDL9RrQStIBBGEhBNqQSReYBU9un7pXjM3mLtGhRD7e7ct8Z8ZzDko5UCg930n3vLhg",
#                     "width": 720
#                 }
#             ],
#             "place_id": "ChIJtQWer0gy_TsRO5dWb2UVv3c",
#             "reference": "ChIJtQWer0gy_TsRO5dWb2UVv3c",
#             "scope": "GOOGLE",
#             "types": [
#                 "sublocality_level_2",
#                 "sublocality",
#                 "political"
#             ],
#             "vicinity": "Rayon Housing Society"
#         }
#     ],
#     "status": "OK"
# }

# %%
idealDF.info()
# len(idealDF)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12 entries, 82 to 544
# Data columns (total 10 columns):
# City          12 non-null object
# Cloudiness    12 non-null int64
# Country       12 non-null object
# Date          12 non-null int64
# Humidity      12 non-null int64
# Lat           12 non-null float64
# Lng           12 non-null float64
# Max Temp      12 non-null float64
# Wind Speed    12 non-null float64
# Hotel         12 non-null object
# dtypes: float64(4), int64(3), object(3)
# memory usage: 1.3+ KB

# %%
idealDF.head(12)
# Out:
#               City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 82          Barela           0      IN  1580053377        59  23.10   80.05
# 104         Tanete           1      ID  1580053381        94  -3.94  119.78
# 161  Makakilo City           1      US  1580053389        93  21.35 -158.09
# 194       Hermanus           0      ZA  1580053395        67 -34.42   19.23
# 200        Labuhan           4      ID  1580053395        83  -6.88  112.21
# 216      Jaisalmer           0      IN  1580053398        23  26.91   70.92
# 234      Tocopilla           1      CL  1580053401        47 -22.09  -70.20
# 338          Sabha           0      LY  1580053417        13  27.04   14.43
# 359     Valparaiso           0      CL  1580053420        64 -33.04  -71.63
# 459   Batemans Bay           1      AU  1580053435        88 -35.72  150.18
# 472          Alofi           1      NU  1580053437       100 -19.06 -169.92
# 544        Veraval           0      IN  1580053452        59  20.90   70.37
#
#      Max Temp  Wind Speed                  Hotel
# 82      66.20        2.24                 Barela
# 104     75.56        1.32            Pangkadjene
# 161     75.20        4.29                Kapolei
# 194     70.00        7.00               Hermanus
# 200     77.97        2.55  Musholla Babut Taubat
# 216     71.15        5.28              Jaisalmer
# 234     73.54        6.78              Tocopilla
# 338     70.05        7.23                  Sabhā
# 359     73.40        6.93             Valparaíso
# 459     66.00        1.99           Batemans Bay
# 472     77.00        5.82                  Alofi
# 544     66.79        4.83                Veraval

# %%
# template to map which fields you want in the poppup
popup_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""

# loop throuh DF to grab the information for each popup marker
location_info = [popup_template.format(**row) for index, row in idealDF.iterrows()]
locations = idealDF[["Lat", "Lng"]]

# %%
# build map. use same info as previous map for layout and display
fig2 = gmaps.figure(layout=figure_layout, zoom_level=1.25, center=(15,45))

# create the hotel layer (not sure why I cannot reference the "location_info" in the )
hotel_layer = gmaps.marker_layer(
    locations, info_box_content= location_info)

# add in the previous heatmap layer and the hotel layer
fig2.add_layer(heat_map)
fig2.add_layer(hotel_layer)
fig2
# Out:
# Figure(layout=FigureLayout(border='10px solid black', height='400px', margin='0 auto 0 auto', padding='1px', width='900px'))
