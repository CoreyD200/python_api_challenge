# %% [markdown]
# # WeatherPy

# %% [markdown]
# Intent: Evaluate various weather data points across the world. Attempt to identify correlation between tempertaure, humidity, cloudiness and windspeed across various longitudes and latitudes

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
from scipy.stats import linregress

# Import API key
#import api_keys

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Find 500 random cities across the globe

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # Replace spaces with %20 to create url correctly 
    #city = city.replace(" ", "%20")
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:

        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 615

# %% [markdown]
# ## API calls to OpenWeatherMap

# %%
# use weather data from OpenWeatherMap API
APIKEY = 'afa48868f123bfcd2ee9acefcf6c6d12'

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + APIKEY + "&q="

# %%
# get a json dump to figure out which keys to use to get the values
response = requests.get(url+"alamogordo")
data=response.json()
print(json.dumps(data, indent=4, sort_keys=True))
# Out:
# {
#     "base": "stations",
#     "clouds": {
#         "all": 1
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 32.9,
#         "lon": -105.96
#     },
#     "dt": 1579915969,
#     "id": 5454627,
#     "main": {
#         "feels_like": 33.76,
#         "humidity": 34,
#         "pressure": 1017,
#         "temp": 42.03,
#         "temp_max": 53.6,
#         "temp_min": 32
#     },
#     "name": "Alamogordo",
#     "sys": {
#         "country": "US",
#         "id": 3270,
#         "sunrise": 1579874620,
#         "sunset": 1579912063,
#         "type": 1
#     },
#     "timezone": -25200,
#     "visibility": 16093,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01n",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 120,
#         "speed": 5.12
#     }
# }

# %%
#Print values to confirm
print(data["name"])
print(data["main"]["humidity"])
print(data['coord']['lat'])
print(data["main"]["temp"])
print(data["clouds"]["all"])
print(data["wind"]["speed"])
# Out:
# Alamogordo
# 34
# 32.9
# 42.03
# 1
# 5.12

# %%
# Create empty lists to append the API data into lists 
city_name = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []

# Set start for counter
record = 1
failed = 0

# Log file print statement
print(f"Beginning Data Retrieval")
print(f"-------------------------------")

#Loop through the cities in the city list 
for city in cities:  
    
    # Try statement to append calls where value is found 
    # Not all calls return data as OpenWeatherMap will not have have records in all the cities generated by CityPy module
    try: 
        response = requests.get(url + city).json() 
        city_name.append(response["name"])
        cloudiness.append(response["clouds"]["all"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        humidity.append(response["main"]["humidity"])
        max_temp.append(response["main"]["temp_max"])
        lat.append(response["coord"]["lat"])
        lng.append(response["coord"]["lon"])
        wind_speed.append(response["wind"]["speed"])
        city_number =(response['id'])
        print(f"Processing Record {record} | city#{city_number}:{city} ")
                
        # Increase counter by one 
        record= record + 1
        
        # Wait a second in loop to not over exceed rate limit of API
        #time.sleep(1.01)
        
    # If city not found output the city name and that it is being skipped, also account add 1 to the failed list
    except:
        failed = failed + 1
        print(f'{city} not found. Moving on to next record')
    #continue

record = record -1    
print('-------------------------')
print(f'Data Retrieval Completed.')
print(f"Successfully retrieved data for {record} cities")
print(f'Unable to retrieve data for {failed} cities from openweathermap.org')
print('-------------------------')
# Out:
# Beginning Data Retrieval
# -------------------------------
# Processing Record 1 | city#2206939:bluff
# Processing Record 2 | city#3366880:hermanus
# Processing Record 3 | city#3985710:cabo san lucas
# Processing Record 4 | city#4035715:avarua
# Processing Record 5 | city#4032243:vaini
# Processing Record 6 | city#5959326:gananoque
# Processing Record 7 | city#286245:sur
# Processing Record 8 | city#964432:port alfred
# Processing Record 9 | city#2155415:new norfolk
# Processing Record 10 | city#1809062:haimen
# Processing Record 11 | city#6949678:taitung
# Processing Record 12 | city#2075265:busselton
# Processing Record 13 | city#3652764:puerto ayora
# Processing Record 14 | city#3347019:namibe
# Processing Record 15 | city#2738381:lata
# Processing Record 16 | city#1015776:bredasdorp
# Processing Record 17 | city#3985168:san patricio
# belushya guba not found. Moving on to next record
# Processing Record 18 | city#1624725:tarakan
# Processing Record 19 | city#1649150:bengkulu
# Processing Record 20 | city#3369157:cape town
# Processing Record 21 | city#5106841:albany
# Processing Record 22 | city#3874787:punta arenas
# Processing Record 23 | city#3893726:constitucion
# Processing Record 24 | city#5848280:kapaa
# grand river south east not found. Moving on to next record
# Processing Record 25 | city#964420:port elizabeth
# Processing Record 26 | city#4011741:durango
# Processing Record 27 | city#4031574:provideniya
# Processing Record 28 | city#1805857:jieshi
# Processing Record 29 | city#315367:erzurum
# Processing Record 30 | city#1282256:hithadhoo
# Processing Record 31 | city#5855927:hilo
# inderborskiy not found. Moving on to next record
# huazolotitlan not found. Moving on to next record
# Processing Record 32 | city#218253:bondo
# Processing Record 33 | city#3883457:lebu
# Processing Record 34 | city#2123278:milkovo
# Processing Record 35 | city#5122534:jamestown
# Processing Record 36 | city#3443061:chuy
# Processing Record 37 | city#6201424:mataura
# Processing Record 38 | city#3361934:saldanha
# Processing Record 39 | city#4030556:rikitea
# Processing Record 40 | city#1714733:dingle
# Processing Record 41 | city#2208248:kaitangata
# Processing Record 42 | city#5882953:aklavik
# Processing Record 43 | city#5855051:ewa beach
# Processing Record 44 | city#3628473:san cristobal
# Processing Record 45 | city#2121373:seymchan
# Processing Record 46 | city#4333811:morgan city
# samusu not found. Moving on to next record
# Processing Record 47 | city#1106677:bambous virieux
# Processing Record 48 | city#6165406:thompson
# Processing Record 49 | city#5880054:barrow
# Processing Record 50 | city#2012530:zhigansk
# Processing Record 51 | city#3424607:tasiilaq
# Processing Record 52 | city#986717:kruisfontein
# taolanaro not found. Moving on to next record
# Processing Record 53 | city#1819729:victoria
# Processing Record 54 | city#542423:krasnoborsk
# Processing Record 55 | city#1738050:miri
# Processing Record 56 | city#2163355:hobart
# Processing Record 57 | city#3833367:ushuaia
# Processing Record 58 | city#2127060:arman
# Processing Record 59 | city#2171099:codrington
# Processing Record 60 | city#4020109:atuona
# Processing Record 61 | city#2017155:saskylakh
# Processing Record 62 | city#1267390:kavaratti
# Processing Record 63 | city#2138592:pouembout
# Processing Record 64 | city#3685223:dibulla
# Processing Record 65 | city#5962442:goderich
# Processing Record 66 | city#1507390:dikson
# Processing Record 67 | city#4034496:fare
# Processing Record 68 | city#3831208:qaanaaq
# Processing Record 69 | city#6355222:yulara
# Processing Record 70 | city#2071860:esperance
# Processing Record 71 | city#3439525:young
# Processing Record 72 | city#546105:nikolskoye
# Processing Record 73 | city#2121025:srednekolymsk
# Processing Record 74 | city#2610806:vagur
# Processing Record 75 | city#6167817:torbay
# Processing Record 76 | city#3445026:vila velha
# Processing Record 77 | city#5919850:chapais
# Processing Record 78 | city#1816890:baoying
# Processing Record 79 | city#5905393:bonavista
# Processing Record 80 | city#364933:umm kaddadah
# kusk not found. Moving on to next record
# mys shmidta not found. Moving on to next record
# Processing Record 81 | city#3471451:arraial do cabo
# Processing Record 82 | city#889942:hwange
# Processing Record 83 | city#2120048:ust-nera
# Processing Record 84 | city#1166164:sanghar
# Processing Record 85 | city#2126199:cherskiy
# Processing Record 86 | city#1504382:kargasok
# Processing Record 87 | city#3372707:ribeira grande
# Processing Record 88 | city#2159220:mackay
# addi ugri not found. Moving on to next record
# Processing Record 89 | city#3516171:tecoanapa
# Processing Record 90 | city#2347954:bama
# Processing Record 91 | city#2137773:vao
# Processing Record 92 | city#3372745:rabo de peixe
# Processing Record 93 | city#777019:vardo
# Processing Record 94 | city#3386213:touros
# Processing Record 95 | city#934479:grand gaube
# Processing Record 96 | city#1735106:georgetown
# Processing Record 97 | city#2074865:carnarvon
# Processing Record 98 | city#157960:kibondo
# Processing Record 99 | city#4004293:ixtapa
# Processing Record 100 | city#3671497:puerto colombia
# Processing Record 101 | city#1079048:ambovombe
# Processing Record 102 | city#1806840:huilong
# vaitupu not found. Moving on to next record
# Processing Record 103 | city#1526041:atasu
# Processing Record 104 | city#1852357:shimoda
# Processing Record 105 | city#3628267:san joaquin
# Processing Record 106 | city#479071:umba
# Processing Record 107 | city#3448903:sao joao da barra
# Processing Record 108 | city#2121385:severo-kurilsk
# palabuhanratu not found. Moving on to next record
# Processing Record 109 | city#4034551:faanui
# Processing Record 110 | city#558885:gremyachinsk
# Processing Record 111 | city#2167426:emerald
# Processing Record 112 | city#1488206:ust-ishim
# Processing Record 113 | city#2126123:chokurdakh
# Processing Record 114 | city#3664243:feijo
# Processing Record 115 | city#5905616:bonnyville
# Processing Record 116 | city#245338:am timan
# Processing Record 117 | city#5546220:saint george
# Processing Record 118 | city#6185377:yellowknife
# Processing Record 119 | city#6089245:norman wells
# Processing Record 120 | city#3397763:jacareacanga
# Processing Record 121 | city#1591474:bac lieu
# Processing Record 122 | city#3109718:santander
# Processing Record 123 | city#2618795:klaksvik
# Processing Record 124 | city#3608828:iralaya
# Processing Record 125 | city#5954718:flin flon
# Processing Record 126 | city#2381334:atar
# Processing Record 127 | city#2629833:husavik
# Processing Record 128 | city#1621313:ambulu
# Processing Record 129 | city#1513491:komsomolskiy
# Processing Record 130 | city#2122090:pevek
# Processing Record 131 | city#2084442:vanimo
# Processing Record 132 | city#2294915:takoradi
# Processing Record 133 | city#2455290:kidal
# illoqqortoormiut not found. Moving on to next record
# Processing Record 134 | city#2126710:beringovskiy
# Processing Record 135 | city#1863997:fukue
# Processing Record 136 | city#143073:ardakan
# Processing Record 137 | city#1006984:east london
# Processing Record 138 | city#3141667:roald
# karamken not found. Moving on to next record
# Processing Record 139 | city#4036284:alofi
# Processing Record 140 | city#1214026:sabang
# Processing Record 141 | city#2173911:broken hill
# Processing Record 142 | city#6111862:port hardy
# Processing Record 143 | city#5563839:fortuna
# Processing Record 144 | city#2374583:bubaque
# Processing Record 145 | city#905846:mpika
# Processing Record 146 | city#3421719:narsaq
# Processing Record 147 | city#2126785:belaya gora
# Processing Record 148 | city#3372472:vila franca do campo
# Processing Record 149 | city#1215350:bireun
# Processing Record 150 | city#6170031:tuktoyaktuk
# Processing Record 151 | city#582447:almaznyy
# Processing Record 152 | city#2128558:otofuke
# Processing Record 153 | city#3984078:santa maria del oro
# tsihombe not found. Moving on to next record
# Processing Record 154 | city#1650434:bambanglipuro
# Processing Record 155 | city#1068971:antsohihy
# Processing Record 156 | city#3466704:castro
# Processing Record 157 | city#1106835:thaba-tseka
# Processing Record 158 | city#64814:bandarbeyla
# Processing Record 159 | city#697126:plakhtiyivka
# Processing Record 160 | city#3155152:gravdal
# Processing Record 161 | city#2145554:ulladulla
# Processing Record 162 | city#934322:mahebourg
# Processing Record 163 | city#5195283:jeannette
# Processing Record 164 | city#3430863:mar del plata
# Processing Record 165 | city#110690:faya
# Processing Record 166 | city#3932145:pisco
# Processing Record 167 | city#6301965:howard springs
# ebano not found. Moving on to next record
# Processing Record 168 | city#3421765:nanortalik
# Processing Record 169 | city#3115824:muros
# Processing Record 170 | city#3451138:rio grande
# Processing Record 171 | city#2110227:butaritari
# Processing Record 172 | city#2123814:leningradskiy
# Processing Record 173 | city#2180991:tolaga bay
# Processing Record 174 | city#140380:bojnurd
# Processing Record 175 | city#5847411:kahului
# Processing Record 176 | city#1052373:beira
# Processing Record 177 | city#3939168:huarmey
# Processing Record 178 | city#2126682:bilibino
# Processing Record 179 | city#2063036:port lincoln
# Processing Record 180 | city#3576994:cockburn town
# Processing Record 181 | city#6096551:pangnirtung
# Processing Record 182 | city#1785036:zhangye
# Processing Record 183 | city#3533462:acapulco
# Processing Record 184 | city#3418910:upernavik
# Processing Record 185 | city#529505:manturovo
# Processing Record 186 | city#1061605:manakara
# Processing Record 187 | city#3868633:vallenar
# Processing Record 188 | city#5367788:lompoc
# Processing Record 189 | city#2191562:dunedin
# Processing Record 190 | city#4957320:bar harbor
# Processing Record 191 | city#2630299:hofn
# Processing Record 192 | city#4016734:bucerias
# Processing Record 193 | city#610298:beyneu
# grand centre not found. Moving on to next record
# Processing Record 194 | city#2039557:khasan
# Processing Record 195 | city#5859699:college
# Processing Record 196 | city#100926:umm lajj
# skalistyy not found. Moving on to next record
# Processing Record 197 | city#2120591:tilichiki
# Processing Record 198 | city#1168700:ormara
# Processing Record 199 | city#3838874:rio cuarto
# Processing Record 200 | city#935214:saint-pierre
# Processing Record 201 | city#6620339:karratha
# Processing Record 202 | city#146209:paralimni
# Processing Record 203 | city#547677:kletskaya
# Processing Record 204 | city#214389:kaniama
# Processing Record 205 | city#3924872:presidente medici
# Processing Record 206 | city#2996268:manica
# Processing Record 207 | city#2400547:gamba
# Processing Record 208 | city#935215:saint-philippe
# Processing Record 209 | city#2264557:ponta do sol
# Processing Record 210 | city#3395458:maragogi
# Processing Record 211 | city#3470137:belmonte
# Processing Record 212 | city#3440777:rocha
# cockburn harbour not found. Moving on to next record
# Processing Record 213 | city#2381972:adrar
# Processing Record 214 | city#2729907:longyearbyen
# tsienyane not found. Moving on to next record
# kazalinsk not found. Moving on to next record
# Processing Record 215 | city#1492499:shagonar
# Processing Record 216 | city#3388847:sao felix do xingu
# Processing Record 217 | city#2112309:katsuura
# Processing Record 218 | city#1630639:pringsewu
# Processing Record 219 | city#1622786:makasar
# Processing Record 220 | city#3836873:tucuman
# Processing Record 221 | city#2180815:tuatapere
# Processing Record 222 | city#535839:leshukonskoye
# Processing Record 223 | city#3686460:chitaga
# Processing Record 224 | city#468180:yekaterinovka
# Processing Record 225 | city#2093685:kokopo
# Processing Record 226 | city#4164601:miramar
# sentyabrskiy not found. Moving on to next record
# Processing Record 227 | city#235826:zemio
# Processing Record 228 | city#5849996:lahaina
# Processing Record 229 | city#2077895:alice springs
# Processing Record 230 | city#3118304:llanes
# Processing Record 231 | city#5866583:kodiak
# Processing Record 232 | city#6148373:sioux lookout
# Processing Record 233 | city#2177069:ballina
# Processing Record 234 | city#5282297:bethel
# Processing Record 235 | city#5197850:lewistown
# samalaeulu not found. Moving on to next record
# Processing Record 236 | city#5972762:hay river
# Processing Record 237 | city#2121324:shebunino
# Processing Record 238 | city#5274867:sturgeon bay
# Processing Record 239 | city#1586443:ca mau
# Processing Record 240 | city#6141439:sault sainte marie
# Processing Record 241 | city#338345:edd
# Processing Record 242 | city#2688250:norrtalje
# Processing Record 243 | city#3679776:la belleza
# Processing Record 244 | city#1586185:cao bang
# harigue not found. Moving on to next record
# Processing Record 245 | city#1270417:hansi
# Processing Record 246 | city#116402:semnan
# Processing Record 247 | city#2980080:saint-francois
# kuche not found. Moving on to next record
# Processing Record 248 | city#583673:aksay
# Processing Record 249 | city#1636308:manokwari
# Processing Record 250 | city#3622537:parrita
# Processing Record 251 | city#3567995:bahia honda
# barentsburg not found. Moving on to next record
# Processing Record 252 | city#3454131:pereira barreto
# Processing Record 253 | city#4031637:lavrentiya
# bolshaya murta not found. Moving on to next record
# Processing Record 254 | city#6149374:slave lake
# Processing Record 255 | city#565783:dobrun
# Processing Record 256 | city#2027042:batagay-alyta
# Processing Record 257 | city#5540831:hurricane
# Processing Record 258 | city#3696183:iquitos
# Processing Record 259 | city#1540711:muravlenko
# Processing Record 260 | city#2070998:geraldton
# Processing Record 261 | city#2231320:garoua
# artyk not found. Moving on to next record
# balimo not found. Moving on to next record
# Processing Record 262 | city#6138980:saint-raymond
# Processing Record 263 | city#2634739:warrington
# Processing Record 264 | city#107304:buraydah
# Processing Record 265 | city#2510573:teguise
# Processing Record 266 | city#175961:mpulungu
# Processing Record 267 | city#2185763:okato
# Processing Record 268 | city#2446796:bilma
# Processing Record 269 | city#2063042:port hedland
# Processing Record 270 | city#1253392:varkkallai
# Processing Record 271 | city#2449893:tessalit
# Processing Record 272 | city#2015306:tiksi
# Processing Record 273 | city#3598787:champerico
# Processing Record 274 | city#2720679:bollnas
# marcona not found. Moving on to next record
# Processing Record 275 | city#3131824:vigrestad
# Processing Record 276 | city#2281120:tabou
# Processing Record 277 | city#3351380:caconda
# Processing Record 278 | city#3906765:quime
# Processing Record 279 | city#2270385:camacha
# Processing Record 280 | city#778707:mehamn
# Processing Record 281 | city#5495360:tucumcari
# Processing Record 282 | city#2439155:tanout
# Processing Record 283 | city#5364271:laguna
# Processing Record 284 | city#2022572:khatanga
# Processing Record 285 | city#3354077:opuwo
# Processing Record 286 | city#2015686:talakan
# Processing Record 287 | city#2416969:nzerekore
# phan rang not found. Moving on to next record
# Processing Record 288 | city#3583446:san miguel
# Processing Record 289 | city#4513583:hamilton
# Processing Record 290 | city#2014624:udachnyy
# Processing Record 291 | city#1529376:korla
# Processing Record 292 | city#64435:berbera
# Processing Record 293 | city#4031742:egvekinot
# Processing Record 294 | city#5338122:clovis
# Processing Record 295 | city#5924351:clyde river
# Processing Record 296 | city#3520994:puerto escondido
# Processing Record 297 | city#2632287:dalvik
# Processing Record 298 | city#2152659:port macquarie
# Processing Record 299 | city#161943:gumdag
# Processing Record 300 | city#2450173:taoudenni
# Processing Record 301 | city#4301317:morehead
# Processing Record 302 | city#3382160:cayenne
# galiwinku not found. Moving on to next record
# Processing Record 303 | city#1043893:lichinga
# Processing Record 304 | city#3036418:aubenas
# saint quentin not found. Moving on to next record
# Processing Record 305 | city#2120047:ust-omchug
# louisbourg not found. Moving on to next record
# Processing Record 306 | city#655823:joensuu
# Processing Record 307 | city#5955902:fort nelson
# luceville not found. Moving on to next record
# Processing Record 308 | city#2094342:kavieng
# Processing Record 309 | city#3419842:sisimiut
# Processing Record 310 | city#3708911:guarare
# Processing Record 311 | city#4618057:dickson
# Processing Record 312 | city#2158767:mareeba
# Processing Record 313 | city#3466980:caravelas
# Processing Record 314 | city#2092164:lorengau
# Processing Record 315 | city#3401548:crateus
# Processing Record 316 | city#3670218:san andres
# Processing Record 317 | city#290030:doha
# Processing Record 318 | city#1253578:vadlapudi
# Processing Record 319 | city#5870133:nome
# Processing Record 320 | city#933995:souillac
# Processing Record 321 | city#3372964:lagoa
# Processing Record 322 | city#3698359:chicama
# Processing Record 323 | city#2063056:port augusta
# yialos not found. Moving on to next record
# Processing Record 324 | city#5866063:kenai
# Processing Record 325 | city#2276492:harper
# tasbuget not found. Moving on to next record
# Processing Record 326 | city#2155562:nelson bay
# Processing Record 327 | city#1488429:uray
# Processing Record 328 | city#3629576:punto fijo
# Processing Record 329 | city#2109701:auki
# Processing Record 330 | city#1486321:yar-sale
# Processing Record 331 | city#3893629:coquimbo
# Processing Record 332 | city#1842966:kijang
# Processing Record 333 | city#3389822:salinopolis
# Processing Record 334 | city#2156643:mount gambier
# Processing Record 335 | city#2022773:khandyga
# Processing Record 336 | city#2396853:omboue
# Processing Record 337 | city#1831112:kampot
# Processing Record 338 | city#921786:mitsamiouli
# saleaula not found. Moving on to next record
# Processing Record 339 | city#2022463:khilok
# Processing Record 340 | city#2181625:te anau
# Processing Record 341 | city#5847486:kailua
# Processing Record 342 | city#3491161:bull savanna
# Processing Record 343 | city#2520597:cadiz
# Processing Record 344 | city#5557293:sitka
# Processing Record 345 | city#2511180:santa cruz de la palma
# Processing Record 346 | city#3100637:darlowo
# amderma not found. Moving on to next record
# Processing Record 347 | city#1488708:ubinskoye
# Processing Record 348 | city#7872020:scharnstein
# Processing Record 349 | city#293842:gat
# Processing Record 350 | city#233019:kaberamaido
# Processing Record 351 | city#2194098:ahipara
# Processing Record 352 | city#2654728:bridlington
# lolua not found. Moving on to next record
# Processing Record 353 | city#104515:mecca
# Processing Record 354 | city#694320:shchebetovka
# Processing Record 355 | city#2098329:daru
# Processing Record 356 | city#1855540:naze
# Processing Record 357 | city#2685750:ostersund
# Processing Record 358 | city#3461370:imbituba
# Processing Record 359 | city#119208:qom
# Processing Record 360 | city#1152222:mae hong son
# Processing Record 361 | city#5861897:fairbanks
# Processing Record 362 | city#1498920:mezhdurechensk
# Processing Record 363 | city#5380437:pacific grove
# maghama not found. Moving on to next record
# Processing Record 364 | city#2288105:grand-lahou
# Processing Record 365 | city#186180:moyale
# Processing Record 366 | city#2507480:algiers
# Processing Record 367 | city#1488903:turukhansk
# attawapiskat not found. Moving on to next record
# Processing Record 368 | city#1106643:quatre cocos
# Processing Record 369 | city#3671437:puerto leguizamo
# Processing Record 370 | city#1160939:iranshahr
# Processing Record 371 | city#2862026:norderstedt
# Processing Record 372 | city#3587498:acajutla
# Processing Record 373 | city#1266366:kohima
# Processing Record 374 | city#86049:jalu
# Processing Record 375 | city#1498161:muzhi
# Processing Record 376 | city#3393692:itarema
# Processing Record 377 | city#4726206:san antonio
# Processing Record 378 | city#4946620:palmer
# Processing Record 379 | city#2112802:hasaki
# Processing Record 380 | city#1151253:phuket
# Processing Record 381 | city#1512101:agirish
# nizhneyansk not found. Moving on to next record
# eskasem not found. Moving on to next record
# Processing Record 382 | city#3188763:trogir
# seaca de padure not found. Moving on to next record
# Processing Record 383 | city#3407378:aracati
# mullaitivu not found. Moving on to next record
# Processing Record 384 | city#2966566:ballyhaunis
# Processing Record 385 | city#3899695:ancud
# Processing Record 386 | city#2030065:mandalgovi
# Processing Record 387 | city#353219:madinat sittah uktubar
# Processing Record 388 | city#2316473:bosobolo
# Processing Record 389 | city#6062563:macamic
# Processing Record 390 | city#3175096:lasa
# Processing Record 391 | city#2026861:berdigestyakh
# Processing Record 392 | city#3522013:palomares
# Processing Record 393 | city#2025630:chara
# Processing Record 394 | city#1526038:atbasar
# Processing Record 395 | city#2647356:hastings
# Processing Record 396 | city#779554:honningsvag
# Processing Record 397 | city#1246294:galle
# Processing Record 398 | city#3980782:ures
# Processing Record 399 | city#57000:hobyo
# Processing Record 400 | city#5110365:broome
# Processing Record 401 | city#1514588:andijon
# Processing Record 402 | city#3423146:ilulissat
# Processing Record 403 | city#1853174:sakaiminato
# Processing Record 404 | city#2178753:kirakira
# Processing Record 405 | city#3395042:mazagao
# Processing Record 406 | city#1863398:haibara
# Processing Record 407 | city#2894897:jever
# Processing Record 408 | city#1641497:kanigoro
# Processing Record 409 | city#3927942:tambopata
# Processing Record 410 | city#3466165:cidreira
# Processing Record 411 | city#3877949:osorno
# Processing Record 412 | city#780687:berlevag
# Processing Record 413 | city#1685422:sulangan
# Processing Record 414 | city#6690296:saint-joseph
# Processing Record 415 | city#1174167:khanpur
# Processing Record 416 | city#3416888:grindavik
# Processing Record 417 | city#5354943:half moon bay
# Processing Record 418 | city#964090:prieska
# Processing Record 419 | city#2317982:yuli
# kemijarvi not found. Moving on to next record
# Processing Record 420 | city#3163146:andenes
# Processing Record 421 | city#3929631:san isidro
# Processing Record 422 | city#6323121:florianopolis
# Processing Record 423 | city#3420768:qasigiannguit
# Processing Record 424 | city#2138555:poum
# Processing Record 425 | city#5970478:harbour breton
# Processing Record 426 | city#4845585:westport
# Processing Record 427 | city#1337281:damphu
# Processing Record 428 | city#3377301:mabaruma
# tumannyy not found. Moving on to next record
# Processing Record 429 | city#541867:krasnyy
# hihifo not found. Moving on to next record
# Processing Record 430 | city#2125693:evensk
# Processing Record 431 | city#1803334:linxi
# Processing Record 432 | city#1214488:meulaboh
# Processing Record 433 | city#2392601:natitingou
# satitoa not found. Moving on to next record
# Processing Record 434 | city#1861280:itoman
# Processing Record 435 | city#2322794:suleja
# Processing Record 436 | city#1705441:lubao
# Processing Record 437 | city#659936:forssa
# Processing Record 438 | city#686090:asau
# Processing Record 439 | city#4269789:coffeyville
# Processing Record 440 | city#1515029:ulaangom
# Processing Record 441 | city#1568770:quang ngai
# Processing Record 442 | city#1278935:amalapuram
# Processing Record 443 | city#1651810:airai
# Processing Record 444 | city#146400:dromolaxia
# Processing Record 445 | city#3374333:praya
# Processing Record 446 | city#1490256:talnakh
# Processing Record 447 | city#2972349:toul
# Processing Record 448 | city#779683:hammerfest
# Processing Record 449 | city#1735902:sibu
# Processing Record 450 | city#1732826:mersing
# Processing Record 451 | city#4465088:elizabeth city
# khormuj not found. Moving on to next record
# Processing Record 452 | city#2641434:northam
# kachikau not found. Moving on to next record
# Processing Record 453 | city#3654410:manta
# umzimvubu not found. Moving on to next record
# Processing Record 454 | city#3421193:paamiut
# kegayli not found. Moving on to next record
# Processing Record 455 | city#3671519:puerto carreno
# Processing Record 456 | city#2686469:ornskoldsvik
# ondorhaan not found. Moving on to next record
# Processing Record 457 | city#219414:basoko
# Processing Record 458 | city#8010683:porto santo
# Processing Record 459 | city#2368035:amlame
# Processing Record 460 | city#2013279:vostok
# Processing Record 461 | city#4021858:guerrero negro
# Processing Record 462 | city#2640351:peterhead
# Processing Record 463 | city#606531:boden
# Processing Record 464 | city#3860443:comodoro rivadavia
# Processing Record 465 | city#1254046:tura
# Processing Record 466 | city#2122614:okha
# Processing Record 467 | city#2392087:porto novo
# Processing Record 468 | city#3835869:santiago del estero
# Processing Record 469 | city#1835848:seoul
# Processing Record 470 | city#3467860:campina verde
# Processing Record 471 | city#1650232:banjar
# Processing Record 472 | city#4026082:lazaro cardenas
# Processing Record 473 | city#1497210:novoagansk
# Processing Record 474 | city#2018925:novokruchininskiy
# Processing Record 475 | city#2396518:port-gentil
# Processing Record 476 | city#2018069:peleduy
# Processing Record 477 | city#1260206:pasighat
# Processing Record 478 | city#1496476:nyagan
# Processing Record 479 | city#2643044:margate
# Processing Record 480 | city#2448083:agadez
# Processing Record 481 | city#6144312:sept-iles
# Processing Record 482 | city#1637001:biak
# Processing Record 483 | city#2219235:awbari
# xiongshi not found. Moving on to next record
# Processing Record 484 | city#4564070:culebra
# Processing Record 485 | city#3356832:henties bay
# Processing Record 486 | city#1684803:tabuk
# Processing Record 487 | city#204953:tshikapa
# Processing Record 488 | city#6255012:flinders
# Processing Record 489 | city#551986:kashin
# Processing Record 490 | city#2026023:bukachacha
# Processing Record 491 | city#7671223:kloulklubed
# Processing Record 492 | city#2063039:port keats
# Processing Record 493 | city#1855612:nara
# Processing Record 494 | city#2510821:soller
# Processing Record 495 | city#934900:nsoko
# Processing Record 496 | city#3489657:lucea
# Processing Record 497 | city#1715015:dicabisagan
# Processing Record 498 | city#1279066:alandi
# Processing Record 499 | city#1045114:inhambane
# Processing Record 500 | city#2139259:ouegoa
# Processing Record 501 | city#1279123:akividu
# Processing Record 502 | city#2027244:bagdarin
# Processing Record 503 | city#124291:mehran
# Processing Record 504 | city#5261790:marathon
# Processing Record 505 | city#3374083:bathsheba
# Processing Record 506 | city#1254709:tezu
# Processing Record 507 | city#1633419:padang
# dien bien not found. Moving on to next record
# Processing Record 508 | city#2027316:ayan
# Processing Record 509 | city#1688696:san policarpo
# karaul not found. Moving on to next record
# Processing Record 510 | city#3038789:abbeville
# Processing Record 511 | city#2090021:namatanai
# Processing Record 512 | city#4781708:richmond
# Processing Record 513 | city#1242110:kalmunai
# Processing Record 514 | city#1067565:beloha
# Processing Record 515 | city#3691582:talara
# Processing Record 516 | city#345353:adet
# Processing Record 517 | city#3833883:trelew
# Processing Record 518 | city#2134814:sola
# Processing Record 519 | city#123941:minab
# Processing Record 520 | city#515879:oktyabrskiy
# Processing Record 521 | city#1065158:farafangana
# Processing Record 522 | city#6126749:rocky mountain house
# Processing Record 523 | city#3386931:tamandare
# pilao arcado not found. Moving on to next record
# Processing Record 524 | city#1786060:yuanping
# Processing Record 525 | city#457955:liepaja
# Processing Record 526 | city#5493403:sunland park
# Processing Record 527 | city#3945985:camana
# Processing Record 528 | city#1519691:sarkand
# Processing Record 529 | city#2258378:loandjili
# Processing Record 530 | city#532860:lyangasovo
# Processing Record 531 | city#3455416:palmeira das missoes
# Processing Record 532 | city#5983607:inuvik
# Processing Record 533 | city#1028434:quelimane
# Processing Record 534 | city#3645528:ciudad guayana
# Processing Record 535 | city#2100765:angoram
# Processing Record 536 | city#634096:tornio
# Processing Record 537 | city#217834:bukama
# Processing Record 538 | city#3372760:praia da vitoria
# Processing Record 539 | city#2388720:boali
# Processing Record 540 | city#576093:blagoyevo
# Processing Record 541 | city#1490796:strezhevoy
# Processing Record 542 | city#3351663:benguela
# Processing Record 543 | city#2396253:tchibanga
# Processing Record 544 | city#1510377:belyy yar
# Processing Record 545 | city#566635:demyanovo
# Processing Record 546 | city#692315:sudak
# Processing Record 547 | city#3180990:campobasso
# Processing Record 548 | city#721349:doboz
# Processing Record 549 | city#988698:knysna
# Processing Record 550 | city#1786657:yinchuan
# Processing Record 551 | city#2094027:kieta
# Processing Record 552 | city#4034188:moerai
# Processing Record 553 | city#2031964:darhan
# Processing Record 554 | city#2079582:alyangula
# Processing Record 555 | city#3577911:dovers
# Processing Record 556 | city#2122605:okhotsk
# Processing Record 557 | city#4033557:tautira
# -------------------------
# Data Retrieval Completed.
# Successfully retrieved data for 557 cities
# Unable to retrieve data for 58 cities from openweathermap.org
# -------------------------

# %%
#create dictionary of values to add to dataFrame
data = {"City": city_name,
    "Cloudiness":cloudiness, 
    "Country":country,
    "Date":date, 
    "Humidity": humidity,
    "Lat":lat, 
    "Lng":lng, 
    "Max Temp": max_temp,
    "Wind Speed":wind_speed
    }

#build DataFrame
weatherDF= pd.DataFrame(data)
weatherDF.head()
# Out:
#              City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0           Bluff         100      NZ  1579890521        96 -46.60  168.33
# 1        Hermanus           0      ZA  1579890522        87 -34.42   19.23
# 2  Cabo San Lucas          40      MX  1579890424        68  22.89 -109.91
# 3          Avarua          83      CK  1579890522        88 -21.21 -159.78
# 4           Vaini          20      TO  1579890522        88 -21.20 -175.20
#
#    Max Temp  Wind Speed
# 0      59.0        4.00
# 1      75.0        3.00
# 2      73.0       10.29
# 3      80.6        6.93
# 4      77.0        5.82

# %%
#weatherDF.to_csv()

# %% [markdown]
#  ##  Plot values in scatter plot

# %% [markdown]
# Create scatter plots to visualize correlation between the following values:
#
#     Max temp to Latitude
#
#     Humidity to Latitude
#
#     Sky coverage to Latitude
#
#     Wind Speed to Latitude

# %%
x = weatherDF['Lat']
y = weatherDF['Max Temp']
cm = plt.cm.get_cmap('RdYlBu_r')

plt.scatter(x,y, c=y,vmin=-45, vmax =105, s=35, cmap=cm, edgecolors='grey')
plt.title('Max Temp by Latitude (01/23/2020)')
plt.ylabel('Max Temp °F')
plt.xlabel('Latitude')
plt.colorbar()
plt.grid(axis = 'x')
plt.show()

# %%
x = weatherDF['Lat']
y = weatherDF['Humidity']
cm = plt.cm.get_cmap('gist_stern')


plt.scatter(x,y, c=y,vmin=-0, vmax =105, s=30, cmap=cm, edgecolors='grey')
plt.title('Humidity by Latitude (01/23/2020)')
plt.ylabel('RH %')
plt.xlabel('Latitude')
plt.grid(axis = 'x')
plt.colorbar()
plt.show()

# %%
x = weatherDF['Lat']
y = weatherDF['Cloudiness']
cm = plt.cm.get_cmap('Blues')


sc = plt.scatter(x,y, c=y,vmin=-0, vmax =100, s=35, cmap=cm, edgecolors='grey')

plt.title('Cloud coverage by Latitude (01/23/2020)')
plt.ylabel('% cloud cover')
plt.xlabel('Latitude')
plt.grid(axis = 'x')
plt.colorbar()

plt.show()

# %%
x = weatherDF['Lat']
y = weatherDF['Wind Speed']
cm = plt.cm.get_cmap('Spectral_r')


plt.scatter(x,y, c=y,vmin=-0, vmax =40, s=25, cmap=cm, edgecolors='grey')

plt.title('Wind Speed by Latitude (01/23/2020)')
plt.ylabel('Wind Speed in MPH')
plt.xlabel('Latitude')
plt.grid(axis = 'x')
plt.colorbar()

plt.show()

# %% [markdown]
# ## Northern and Southern hemisphere viewed individually

# %%
#create seperate DF's for each hemisphere
northDF=weatherDF.loc[weatherDF['Lat']>=0]
southDF=weatherDF.loc[weatherDF['Lat']<0]

# %%
def lin_regress(x_val,y_val):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_val, y_val)
    regress_values = x_val * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# %%
print(lin_regress)
# Out:
# <function lin_regress at 0x00000242DDBEE730>

# %% [markdown]
# ### Temps

# %%
x_val = northDF['Lat']
y_val = northDF['Max Temp']
#lin_regress
slope, intercept, rvalue, pvalue, stderr = linregress(x_val, y_val)
regress_values = x_val * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

cm = plt.cm.get_cmap('RdYlBu_r')

plt.scatter(x_val,y_val, c=y_val,vmin=-45, vmax =105, s=35, cmap=cm, edgecolors='grey')
plt.plot(x_val,regress_values,"black")
plt.annotate(line_eq,(0,-20),fontsize=15,color="Black")
plt.title('Temps vs Latitute (N)')
plt.xlabel('Northern Latitude')
plt.ylabel('Max Temp in °F')
plt.colorbar()
print(f"The r-squared is: {rvalue}")
plt.grid(axis = 'x')

plt.show()
# Out:
# The r-squared is: -0.8720471266031804

# %% [markdown]
# Strong correlation between temperatures and latitude in the Northern Hemisphere.

# %%
x_val = southDF['Lat']
y_val = southDF['Max Temp']
#lin_regress
slope, intercept, rvalue, pvalue, stderr = linregress(x_val, y_val)
regress_values = x_val * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

cm = plt.cm.get_cmap('RdYlBu_r')

plt.scatter(x_val,y_val, c=y_val,vmin=-45, vmax =105, s=35, cmap=cm, edgecolors='grey')
plt.plot(x_val,regress_values,"black")
plt.annotate(line_eq,(-45,40),fontsize=15,color="Black")
plt.title('Temps vs Latitude (S)')
plt.xlabel('Southern Latitude')
plt.ylabel('Max Temp in °F')
plt.colorbar()
print(f"The r-squared is: {rvalue}")
plt.grid(axis = 'x')

plt.show()
# Out:
# The r-squared is: 0.3916685344301117

# %% [markdown]
# Trend line show similar trend line as you near the equator. One noticable difference is the lack of values below the 50th southern parallel.

# %% [markdown]
# ### Humidity

# %%
x_val = northDF['Lat']
y_val = northDF['Humidity']
#lin_regress
slope, intercept, rvalue, pvalue, stderr = linregress(x_val, y_val)
regress_values = x_val * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

cm = plt.cm.get_cmap('RdYlBu')

plt.scatter(x_val,y_val, c=y_val,vmin=0, vmax =100, s=35, cmap=cm, edgecolors='grey')
plt.plot(x_val,regress_values,"black")
plt.annotate(line_eq,(40,20),fontsize=13,color="Black")
plt.title('Humidity vs Latitude (N)')
plt.xlabel('Northern Latitude')
plt.ylabel('RH %')
plt.colorbar()
print(f"The r-squared is: {(rvalue)*2}")
plt.grid(axis = 'x')
# Out:
# The r-squared is: 0.8739440842721266

# %%
x_val = southDF['Lat']
y_val = southDF['Humidity']
#lin_regress
slope, intercept, rvalue, pvalue, stderr = linregress(x_val, y_val)
regress_values = x_val * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

cm = plt.cm.get_cmap('RdYlBu')

plt.scatter(x_val,y_val, c=y_val,vmin=-0, vmax =105, s=35, cmap=cm, edgecolors='grey')
plt.plot(x_val,regress_values,"black")
plt.annotate(line_eq,(-28,38),fontsize=13,color="Black")
plt.title('Humidity vs Latitude (S)')
plt.xlabel('Southern Latitude')
plt.ylabel('RH %')
plt.colorbar()
print(f"The r-squared is: {rvalue}*2")
plt.grid(axis = 'x')
# Out:
# The r-squared is: 0.21847963440433982*2

# %% [markdown]
# Humidity does have small correlation to latitude. Both the charts and the r-squared values indicate this is more significant in the northern hemisphere.

# %% [markdown]
# ______________________________________________________________________________________________________

# %% [markdown]
# ### Cloudiness

# %%
x_val = northDF['Lat']
y_val = northDF['Cloudiness']
#lin_regress
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_val, y_val)
regress_values = x_val * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

cm = plt.cm.get_cmap('Blues_r')

plt.scatter(x_val,y_val, c=y_val,vmin=-45, vmax =105, s=30, cmap=cm, edgecolors='grey')
plt.plot(x_val,regress_values,"black")
plt.annotate(line_eq,(40,45),fontsize=13,color="Black")
plt.title('Cloud cover vs Latitude (N)')
plt.xlabel('Northern Latitude')
plt.ylabel('Sky coverage %')
plt.colorbar()
print(f"The r-squared is: {rvalue}")
plt.grid(axis = 'x')
# Out:
# The r-squared is: 0.2141033190925932

# %%
x_val = southDF['Lat']
y_val = southDF['Cloudiness']
#lin_regress
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_val, y_val)
regress_values = x_val * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

cm = plt.cm.get_cmap('Blues_r')

plt.scatter(x_val,y_val, c=y_val,vmin=-0, vmax =105, s=35, cmap=cm, edgecolors='grey')
plt.plot(x_val,regress_values,"black")
plt.annotate(line_eq,(-55,83),fontsize=13,color="Black")
plt.title('Cloud cover vs Latitude (S)')
plt.xlabel('Southern Latitude')
plt.ylabel('Sky coverage %')
plt.colorbar()
print(f"The r-squared is: {rvalue}")
plt.grid(axis = 'x')
# Out:
# The r-squared is: 0.0858474117786893

# %% [markdown]
# Very low r-squared in both hemispheres does not support a correlation between cloud cover and latitude within this data set.

# %% [markdown]
# ______________________________________________________________________________________________________

# %% [markdown]
# ### Wind Speed

# %%
x_val = northDF['Lat']
y_val = northDF['Wind Speed']
#lin_regress
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_val, y_val)
regress_values = x_val * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

cm = plt.cm.get_cmap('Spectral_r')

scn= plt.scatter(x_val,y_val, c=y_val,vmin=-0, vmax =50, s=35, cmap=cm, edgecolors='grey')
plt.plot(x_val,regress_values,"black")
plt.annotate(line_eq,(15,25),fontsize=15,color="Black")
plt.title('Wind Speed vs Latitude (N)')
plt.xlabel('Northern Latitude')
plt.ylabel('MPH')
plt.colorbar()
print(f"The r-squared is: {rvalue}")
plt.grid(axis = 'x')
# Out:
# The r-squared is: 0.12140787802140306

# %%
x_val = southDF['Lat']
y_val = southDF['Wind Speed']
#lin_regress
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_val, y_val)
regress_values = x_val * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

cm = plt.cm.get_cmap('Spectral_r')

scs=plt.scatter(x_val,y_val, c=y_val,vmin=-0, vmax =50, s=35, cmap=cm, edgecolors='grey')
plt.plot(x_val,regress_values,"black")
plt.annotate(line_eq,(-30,25),fontsize=15,color="Black")
plt.title('Wind Speed vs Latitude (S)')
plt.xlabel('Southern Latitude')
plt.ylabel('MPH')
plt.colorbar()
print(f"The r-squared is: {rvalue}")
plt.grid(axis = 'x')
# Out:
# The r-squared is: -0.20557611772298273

# %% [markdown]
# Very low r-squared in both hemispheres does not support a correlation between wind speed and latitude within this dataset.
